# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
mu=0  #正态分布的均值
sigma=1  #正态分布的标准差

# %%
samples=10000
s=np.random.normal(mu, sigma, samples)  #生成正态分布随机数

# %%
plt.hist(s, bins=100)
plt.show()

# %%
x=np.linspace(mu-3*sigma, mu+3*sigma, 100)
y=np.exp(-(x-mu)**2/(2*sigma**2))/(math.sqrt(2*math.pi)*sigma)  #正态分布的概率密度函数

# %%
plt.plot(x, y, "g", linewidth=2)
plt.grid(True)
plt.show()
